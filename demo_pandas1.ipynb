# %%
import pandas as pd

# %%
events_df = pd.read_csv(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\events.csv')

# %%
events_df.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id
# 0    2026-01-13 10:00          I001
# 1    2026-01-16 14:00          I001
# 2    2026-01-19 10:00          I003
# 3    2026-01-22 10:00          I002
# 4    2026-01-25 14:00          I002

# %%
# Number of records

print(events_df.count())
# Out:
# event_id               12
# topic                  12
# city                   12
# venue_capacity         12
# scheduled_date_time    12
# instructor_id          12
# dtype: int64

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     object
#  2   city                 12 non-null     object
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     object
#  5   instructor_id        12 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 708.0+ bytes

# %%
channels_df = pd.read_csv(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\channels.csv')

# %%
channels_df.head()
# Out:
#   event_id  channel  spend  impressions
# 0     E001    email   7000        35000
# 1     E001   social   5000        10000
# 2     E001  partner   7000        20000
# 3     E002    email   5000        35000
# 4     E002   social   5000        10000

# %%
events_df.describe()
# Out:
#        venue_capacity
# count       12.000000
# mean        45.833333
# std         10.836247
# min         30.000000
# 25%         40.000000
# 50%         45.000000
# 75%         52.500000
# max         60.000000

# %%
attendees_df = pd.read_json(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\attendees.json')

# %%
attendees_df['notes']
# Out:
# 0     Reached via partner. Promo=STUDENT15; Phone:+9...
# 1     Reached via email. Promo=STUDENT15; Phone:+91-...
# 2     Reached via partner. Promo=STUDENT15; Phone:+9...
# 3     Reached via email. Promo=NA; Phone:+91-7059780...
# 4     Reached via partner. Promo=NA; Phone:+91-97425...
# 5     Reached via partner. Promo=NY25; Phone:+91-978...
# 6     Reached via email. Promo=EARLY10; Phone:+91-71...
# 7     Reached via social. Promo=NA; Phone:+91-859348...
# 8     Reached via social. Promo=NA; Phone:+91-820147...
# 9     Reached via email. Promo=STUDENT15; Phone:+91-...
# 10    Reached via email. Promo=EARLY10; Phone:+91-89...
# 11    Reached via email. Promo=NY25; Phone:+91-94248...
# 12    Reached via email. Promo=EARLY10; Phone:+91-81...
# 13    Reached via email. Promo=EARLY10; Phone:+91-85...
# 14    Reached via email. Promo=NY25; Phone:+91-88080...
# 15    Reached via partner. Promo=EARLY10; Phone:+91-...
# 16    Reached via email. Promo=NA; Phone:+91-8724932...
# ...

# %%
pricing_df = pd.read_csv(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\pricing.csv')
registrations_df = pd.read_csv(r'C:\Users\VishwasKSingh\Workspace\temp\my_app\data\registrations.csv')

# %%
events_df.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id
# 0    2026-01-13 10:00          I001
# 1    2026-01-16 14:00          I001
# 2    2026-01-19 10:00          I003
# 3    2026-01-22 10:00          I002
# 4    2026-01-25 14:00          I002

# %%
registrations_df.head()
# Out:
#      reg_id event_id     attendee_email     reg_timestamp payment_status  \
# 0  RE001000     E001  user0@example.com  2025-12-31 10:00           paid
# 1  RE001001     E001  user1@example.com  2025-12-18 10:00      cancelled
# 2  RE001002     E001  user2@example.com  2025-12-23 10:00        pending
# 3  RE001003     E001  user3@example.com  2026-01-11 10:00           paid
# 4  RE001004     E001  user4@example.com  2025-12-14 10:00        pending
#
#   ticket_type
# 0   earlybird
# 1    standard
# 2     student
# 3     student
# 4    standard

# %%
channels_df.head()
# Out:
#   event_id  channel  spend  impressions
# 0     E001    email   7000        35000
# 1     E001   social   5000        10000
# 2     E001  partner   7000        20000
# 3     E002    email   5000        35000
# 4     E002   social   5000        10000

# %%
import matplotlib.pyplot as plt

# %%
x = ['A','B','C','D']
y = [10,20,40,80]

plt.figure()
plt.plot(x,y, '-ro')
plt.xlabel('Item')
plt.ylabel('counts')
plt.show()

# %%
x = ['A','B','C','D']
y = [10,20,40,80]

plt.figure()
plt.bar(x,y)
plt.xlabel('Item')
plt.ylabel('counts')
plt.show()

# %%
x = ['A','B','C','D']
y = [10,20,40,80]

plt.figure()
plt.pie(y)
plt.xlabel('Item')
plt.ylabel('counts')
plt.show()

# %%
x = ['A','B','C','D']
y = [10,20,40,80]

plt.figure()
plt.scatter(x,y)
plt.xlabel('Item')
plt.ylabel('counts')
plt.show()
